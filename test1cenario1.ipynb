# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
#necessario por causa do metodo de avaliaçao
from sklearn.model_selection import KFold
from sklearn.metrics import (
        make_scorer,
        confusion_matrix, 
        cohen_kappa_score, 
        accuracy_score, 
        precision_score, 
        recall_score, 
        f1_score, 
        roc_auc_score
)
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier # decision trees for classification
from sklearn.neural_network import  MLPClassifier # neural networks for classification
from sklearn.naive_bayes import GaussianNB # naive bayes for classification
from sklearn.svm import SVC # support vector machines for classification

# %%
#metricas regressao
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def custom_regression_metrics(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    return mse, mae, r2

# %%
#metricas classificação
def specificity_score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    return tn / (tn+fp)

# %%
#Metricas regressao
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

REGRESSION_METRICS = {
    "MSE": make_scorer(mean_squared_error),
    "MAE": make_scorer(mean_absolute_error),
    "R2": make_scorer(r2_score)
}

# %%
METRICS = {
        "accuracy": make_scorer(accuracy_score),
        "precision": make_scorer(precision_score),
        "recall": make_scorer(recall_score),
        "f1": make_scorer(f1_score),
        "AUC": make_scorer(roc_auc_score, needs_proba=True),
        "specificity": make_scorer(specificity_score),
        "kappa":make_scorer(cohen_kappa_score)
}

# %%
d = pd.read_csv("PREV1.csv")
d
# Out:
#        full_name  registered_year  engine_capacity  insurance  \
# 0       3.086522           2019.0           1199.0   0.256633
# 1       2.403638           2018.0           1199.0   1.306401
# 2       2.583846           2015.0           1497.0   0.256633
# 3       3.650793           2021.0           1956.0   0.256633
# 4       2.747703           2019.0           1197.0   1.306401
# ...          ...              ...              ...        ...
# 13420   3.650793           2021.0           2199.0   0.256633
# 13421   2.951823           2017.0           1197.0   0.256633
# 13422   3.282816           2017.0           1498.0   0.445408
# 13423   2.747703           2017.0           1248.0   0.445408
# 13424   2.428944           2015.0           1198.0   0.445408
#
#        transmission_type  kms_driven  owner_type  fuel_type  max_power  seats  \
# 0               0.131359     30910.0    0.150465   0.180334       83.8    5.0
# 1               0.131359     48089.0    1.365236   0.180334       88.7    5.0
# 2               0.131359     51000.0    0.620328   0.180334      117.3    5.0
# 3               0.583102     30000.0    0.150465   0.514919      167.6    7.0
# 4               0.583102     61113.0    0.150465   0.180334       83.1    5.0
# ...                  ...         ...         ...        ...        ...    ...
# 13420           0.583102     80000.0    0.620328   0.514919      197.2    7.0
# 13421           0.131359     17923.0    0.150465   0.180334       81.8    5.0
# 13422           0.131359     63389.0    0.620328   0.514919      108.6    5.0
# 13423           0.131359     40000.0    0.620328   0.514919       88.5    5.0
# 13424           0.131359     33046.0    0.150465   0.180334       86.7    5.0
#
#        mileage  body_type      city  resale_price_Lakh
# 0        23.84   0.364112  1.096102               5.66
# 1        17.50   0.598869  1.281577               6.64
# 2        17.40   0.578053  0.922710               5.65
# 3        14.08   0.598869  0.922710              23.00
# 4        21.40   0.364112  1.170307               6.87
# ...        ...        ...       ...                ...
# 13420    14.11   1.347597  1.027199              26.50
# 13421    18.60   0.364112  1.223199               5.87
# 13422    21.13   0.578053  1.027199               7.43
# 13423    24.30   0.598869  0.868320               9.45
# 13424    18.00   0.578053  0.868320               4.55
#
# [13425 rows x 14 columns]

# %%
X, y = d.drop("resale_price_Lakh", axis=1), d["resale_price_Lakh"]

# %%
#Classificação
splitter = StratifiedKFold(n_splits=10, shuffle=True, random_state=1234)

# Utilize KFold para um problema de regressão
kf = KFold(n_splits=10, shuffle=True, random_state=1234)

# %%
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_validate
import pandas as pd
# Carregar o conjunto de teste a partir de um arquivo CSV
df_test = pd.read_csv('test.csv') 

# Utilize KFold para um problema de regressão
kf = KFold(n_splits=10, shuffle=True, random_state=1234)

# Continue com a validação cruzada e a avaliação de métricas
dt_regressor = DecisionTreeRegressor(max_depth=3, random_state=1234)
scores = cross_validate(dt_regressor, X, y, cv=kf, scoring=REGRESSION_METRICS)
dt_scores = pd.DataFrame(scores)
print(pd.DataFrame(dt_scores.mean()).T)

# Treinar o modelo final usando todo o conjunto de dados
final_model = DecisionTreeRegressor(max_depth=3, random_state=1234)
final_model.fit(X, y)

# Suponhamos que você tenha um conjunto de teste df_test
# Certifique-se de que df_test tem as mesmas features que X
# Out:
#    fit_time  score_time   test_MSE  test_MAE   test_R2
# 0  0.018191    0.002117  22.935042  2.678858  0.734172
# DecisionTreeRegressor(max_depth=3, random_state=1234)

# %%
print(X)
# Check data types
data_types = X.dtypes
print("Data type by column:")
print(data_types)
# Out:
#        full_name  registered_year  engine_capacity  insurance  \
# 0       3.086522           2019.0           1199.0   0.256633
# 1       2.403638           2018.0           1199.0   1.306401
# 2       2.583846           2015.0           1497.0   0.256633
# 3       3.650793           2021.0           1956.0   0.256633
# 4       2.747703           2019.0           1197.0   1.306401
# ...          ...              ...              ...        ...
# 13420   3.650793           2021.0           2199.0   0.256633
# 13421   2.951823           2017.0           1197.0   0.256633
# 13422   3.282816           2017.0           1498.0   0.445408
# 13423   2.747703           2017.0           1248.0   0.445408
# 13424   2.428944           2015.0           1198.0   0.445408
#
#        transmission_type  kms_driven  owner_type  fuel_type  max_power  seats  \
# 0               0.131359     30910.0    0.150465   0.180334       83.8    5.0
# 1               0.131359     48089.0    1.365236   0.180334       88.7    5.0
# 2               0.131359     51000.0    0.620328   0.180334      117.3    5.0
# 3               0.583102     30000.0    0.150465   0.514919      167.6    7.0
# 4               0.583102     61113.0    0.150465   0.180334       83.1    5.0
# ...                  ...         ...         ...        ...        ...    ...
# 13420           0.583102     80000.0    0.620328   0.514919      197.2    7.0
# 13421           0.131359     17923.0    0.150465   0.180334       81.8    5.0
# 13422           0.131359     63389.0    0.620328   0.514919      108.6    5.0
# 13423           0.131359     40000.0    0.620328   0.514919       88.5    5.0
# 13424           0.131359     33046.0    0.150465   0.180334       86.7    5.0
#
#        mileage  body_type      city
# 0        23.84   0.364112  1.096102
# 1        17.50   0.598869  1.281577
# 2        17.40   0.578053  0.922710
# 3        14.08   0.598869  0.922710
# 4        21.40   0.364112  1.170307
# ...        ...        ...       ...
# 13420    14.11   1.347597  1.027199
# 13421    18.60   0.364112  1.223199
# 13422    21.13   0.578053  1.027199
# 13423    24.30   0.598869  0.868320
# 13424    18.00   0.578053  0.868320
#
# [13425 rows x 13 columns]
# Data type by column:
# full_name            float64
# registered_year      float64
# engine_capacity      float64
# insurance            float64
# transmission_type    float64
# kms_driven           float64
# owner_type           float64
# fuel_type            float64
# max_power            float64
# seats                float64
# mileage              float64
# body_type            float64
# city                 float64
# dtype: object

# %%
from sklearn.tree import DecisionTreeRegressor
import pandas as pd

# Carregar o conjunto de teste a partir de um arquivo CSV
df_test = pd.read_csv('test.csv') 
id_column = df_test['ID']  # Supondo que 'Id' seja o nome da coluna que você deseja adicionar


# Adicionando a coluna 'ID' ao DataFrame 'X'
X['ID'] = id_column

print(X)
# Check data types
data_types = X.dtypes
print("Data type by column:")
print(data_types)
# Out:
#        full_name  registered_year  engine_capacity  insurance  \
# 0       3.086522           2019.0           1199.0   0.256633
# 1       2.403638           2018.0           1199.0   1.306401
# 2       2.583846           2015.0           1497.0   0.256633
# 3       3.650793           2021.0           1956.0   0.256633
# 4       2.747703           2019.0           1197.0   1.306401
# ...          ...              ...              ...        ...
# 13420   3.650793           2021.0           2199.0   0.256633
# 13421   2.951823           2017.0           1197.0   0.256633
# 13422   3.282816           2017.0           1498.0   0.445408
# 13423   2.747703           2017.0           1248.0   0.445408
# 13424   2.428944           2015.0           1198.0   0.445408
#
#        transmission_type  kms_driven  owner_type  fuel_type  max_power  seats  \
# 0               0.131359     30910.0    0.150465   0.180334       83.8    5.0
# 1               0.131359     48089.0    1.365236   0.180334       88.7    5.0
# 2               0.131359     51000.0    0.620328   0.180334      117.3    5.0
# 3               0.583102     30000.0    0.150465   0.514919      167.6    7.0
# 4               0.583102     61113.0    0.150465   0.180334       83.1    5.0
# ...                  ...         ...         ...        ...        ...    ...
# 13420           0.583102     80000.0    0.620328   0.514919      197.2    7.0
# 13421           0.131359     17923.0    0.150465   0.180334       81.8    5.0
# 13422           0.131359     63389.0    0.620328   0.514919      108.6    5.0
# 13423           0.131359     40000.0    0.620328   0.514919       88.5    5.0
# 13424           0.131359     33046.0    0.150465   0.180334       86.7    5.0
#
#        mileage  body_type      city   ID
# 0        23.84   0.364112  1.096102  0.0
# 1        17.50   0.598869  1.281577  1.0
# 2        17.40   0.578053  0.922710  2.0
# 3        14.08   0.598869  0.922710  3.0
# 4        21.40   0.364112  1.170307  4.0
# ...        ...        ...       ...  ...
# 13420    14.11   1.347597  1.027199  NaN
# 13421    18.60   0.364112  1.223199  NaN
# 13422    21.13   0.578053  1.027199  NaN
# 13423    24.30   0.598869  0.868320  NaN
# 13424    18.00   0.578053  0.868320  NaN
#
# [13425 rows x 14 columns]
# Data type by column:
# full_name            float64
# registered_year      float64
# engine_capacity      float64
# insurance            float64
# transmission_type    float64
# kms_driven           float64
# owner_type           float64
# fuel_type            float64
# max_power            float64
# seats                float64
# mileage              float64
# body_type            float64
# city                 float64
# ID                   float64
# dtype: object

# %%
df_test=X
print(df_test)
# Check data types
data_types = df_test.dtypes
print("Data type by column:")
print(data_types)
# Out:
#        full_name  registered_year  engine_capacity  insurance  \
# 0       3.086522           2019.0           1199.0   0.256633
# 1       2.403638           2018.0           1199.0   1.306401
# 2       2.583846           2015.0           1497.0   0.256633
# 3       3.650793           2021.0           1956.0   0.256633
# 4       2.747703           2019.0           1197.0   1.306401
# ...          ...              ...              ...        ...
# 13420   3.650793           2021.0           2199.0   0.256633
# 13421   2.951823           2017.0           1197.0   0.256633
# 13422   3.282816           2017.0           1498.0   0.445408
# 13423   2.747703           2017.0           1248.0   0.445408
# 13424   2.428944           2015.0           1198.0   0.445408
#
#        transmission_type  kms_driven  owner_type  fuel_type  max_power  seats  \
# 0               0.131359     30910.0    0.150465   0.180334       83.8    5.0
# 1               0.131359     48089.0    1.365236   0.180334       88.7    5.0
# 2               0.131359     51000.0    0.620328   0.180334      117.3    5.0
# 3               0.583102     30000.0    0.150465   0.514919      167.6    7.0
# 4               0.583102     61113.0    0.150465   0.180334       83.1    5.0
# ...                  ...         ...         ...        ...        ...    ...
# 13420           0.583102     80000.0    0.620328   0.514919      197.2    7.0
# 13421           0.131359     17923.0    0.150465   0.180334       81.8    5.0
# 13422           0.131359     63389.0    0.620328   0.514919      108.6    5.0
# 13423           0.131359     40000.0    0.620328   0.514919       88.5    5.0
# 13424           0.131359     33046.0    0.150465   0.180334       86.7    5.0
#
#        mileage  body_type      city   ID
# 0        23.84   0.364112  1.096102  0.0
# 1        17.50   0.598869  1.281577  1.0
# 2        17.40   0.578053  0.922710  2.0
# 3        14.08   0.598869  0.922710  3.0
# 4        21.40   0.364112  1.170307  4.0
# ...        ...        ...       ...  ...
# 13420    14.11   1.347597  1.027199  NaN
# 13421    18.60   0.364112  1.223199  NaN
# 13422    21.13   0.578053  1.027199  NaN
# 13423    24.30   0.598869  0.868320  NaN
# 13424    18.00   0.578053  0.868320  NaN
#
# [13425 rows x 14 columns]
# Data type by column:
# full_name            float64
# registered_year      float64
# engine_capacity      float64
# insurance            float64
# transmission_type    float64
# kms_driven           float64
# owner_type           float64
# fuel_type            float64
# max_power            float64
# seats                float64
# mileage              float64
# body_type            float64
# city                 float64
# ID                   float64
# dtype: object

# %%
from sklearn import tree
clf = tree.DecisionTreeRegressor()
clf = clf.fit(X, y)
predictions=clf.predict(df_test)

# %%
print(len(id_column))  # Check the length of id_column
print(len(predictions))  # Check the length of predictions
# Out:
# 3490
# 13425

# %%
min_length = min(len(predictions), len(id_column))
predictions = predictions[:min_length]
id_column = id_column[:min_length]

df_predictions = pd.DataFrame({"ID": id_column, "prediction": predictions})

# %%
print(df_predictions)
# Out:
#         ID  prediction
# 0        0    6.850143
# 1        1    6.850143
# 2        2    6.850143
# 3        3    6.850143
# 4        4    6.850143
# ...    ...         ...
# 3485  3485    6.850143
# 3486  3486    6.850143
# 3487  3487    6.850143
# 3488  3488   20.683333
# 3489  3489    6.850143
#
# [3490 rows x 2 columns]

# %%
# Exporte o DataFrame para um arquivo CSV
df_predictions.to_csv('predictionsCenario1.csv', index=False)
