# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import re

# %%
df = pd.read_csv('train.csv')

# %%
import pandas as pd

# Supondo que 'data' seja o seu DataFrame e 'engine_capacity' seja o nome da coluna
# Substitua 'data' e 'engine_capacity' com os seus dados reais
valores_unicos = df['mileage'].unique()

print("Valores únicos na coluna 'engine_capacity':")
print(valores_unicos)
# Out:
# Valores únicos na coluna 'engine_capacity':
# ['23.84 kmpl' '17.5 kmpl' '17.4 kmpl' '14.08 kmpl' '21.4 kmpl'
#  '17.66 kmpl' '17.52 kmpl' '16.09 kmpl' '22.48 kmpl' '18.24 kmpl'
#  '21.74 kmpl' '19.27 kmpl' '23.01 kmpl' '21.5 kmpl' '22.38 kmpl' '18 kmpl'
#  '22.41 kmpl' '11 kmpl' '27.39 kmpl' '16.55 kmpl' '19 kmpl' '23.59 kmpl'
#  '15.1 kmpl' '18.6 kmpl' nan '20.36 kmpl' '16.38 kmpl' '18.2 kmpl'
#  '22.77 kmpl' '17 kmpl' '17.6 kmpl' '18.15 kmpl' '19.34 kmpl' '11.3 kmpl'
#  '20.7 kmpl' '22.9 kmpl' '14.84 kmpl' '20.71 kmpl' '17.7 kmpl' '15.8 kmpl'
#  '17.05 kmpl' '18.16 kmpl' '16 kmpl' '18.7 kmpl' '14.8 kmpl' '15.74 kmpl'
#  '18.3 kmpl' '15.6 kmpl' '15.68 kmpl' '18.9 kmpl' '24.2 kmpl' '14.11 kmpl'
#  '16.35 kmpl' '22.05 kmpl' '17.01 kmpl' '23.95 kmpl' '19.17 kmpl'
#  '17.8 kmpl' '20 kmpl' '26.1 kmpl' '19.67 kmpl' '12.8 kmpl' '22.07 kmpl'
#  '26.2 kmpl' '18.06 kmpl' '14.5 kmpl' '34.05 kmpl' '20.51 kmpl' '33 kmpl'
#  '13.68 kmpl' '16.36 kmpl' '25.8 kmpl' '17.3 kmpl' '21.21 kmpl'
#  '16.47 kmpl' '13.9 kmpl' '23 kmpl' '20.3 kmpl' '23.1 kmpl' '23.2 kmpl'
#  '23.65 kmpl' '21.9 kmpl' '19.81 kmpl' '30.48 km/kg' '32.52 kmpl'
#  '18.88 kmpl' '33.54 kmpl' '12.95 kmpl' '24.7 kmpl' '14.1 kmpl'
#  '21.94 km/kg' '20.89 kmpl' '22.74 kmpl' '20.14 kmpl' '20.92 kmpl'
#  '13.79 kmpl' '21.1 kmpl' '22.54 kmpl' '18.97 kmpl' '17.21 kmpl'
#  '17.92 kmpl' '25.2 kmpl' '19.7 kmpl' '24.3 kmpl' '18.41 kmpl'
#  '25.24 kmpl' '21.79 kmpl' '19.3 kmpl' '19.6 kmpl' '17.36 kmpl'
#  '12.55 kmpl' '20.8 kmpl' '19.01 kmpl' '24 kmpl' '14.67 kmpl' '22.3 kmpl'
#  '15.37 kmpl' '19.4 kmpl' '13.5 kmpl' '22.1 kmpl' '28.4 kmpl' '20.4 kmpl'
#  '22 kmpl' '14.7 kmpl' '26.6 kmpl' '18.1 kmpl' '17.11 kmpl' '10.91 kmpl'
#  '20.45 kmpl' '15.64 kmpl' '16.8 kmpl' '20.08 kmpl' '20.5 kmpl'
#  '20.1 kmpl' '15.29 kmpl' '20.73 kmpl' '9.4 kmpl' '19.02 kmpl' '13 kmpl'
#  '18.5 kmpl' '19.56 kmpl' '13.93 kmpl' '14.82 kmpl' '14.47 kmpl'
#  '25.44 kmpl' '19.33 kmpl' '21.01 kmpl' '16.2 kmpl' '31.79 kmpl'
#  '26.59 kmpl' '17.29 kmpl' '19.1 kmpl' '13.96 kmpl' '17.03 kmpl' '26 kmpl'
#  '12.07 kmpl' '19.15 kmpl' '17.69 kmpl' '17.43 kmpl' '12.7 kmpl'
#  '10.1 kmpl' '26.3 kmpl' '16.1 kmpl' '13.7 kmpl' '25.01 kmpl' '19.16 kmpl'
#  '28.09 kmpl' '16.82 kmpl' '31.2 kmpl' '13.24 kmpl' '21.7 kmpl'
#  '15.26 kmpl' '17.1 kmpl' '20.77 kmpl' '16.9 kmpl' '12.99 kmpl'
#  '21.72 kmpl' '22.7 kmpl' '24.39 kmpl' '16.77 kmpl' '17.84 kmpl'
#  '13.6 kmpl' '25.4 kmpl' '28 km/kg' '25 kmpl' '19.5 kmpl' '14.3 kmpl'
#  '18.78 kmpl' '16.5 kmpl' '25.83 kmpl' '15.85 kmpl' '16.46 kmpl'
#  '24.76 kmpl' '12.2 kmpl' '15.7 kmpl' '17.57 kmpl' '23.7 kmpl'
#  '18.49 kmpl' '16.98 kmpl' '19.2 kmpl' '18.23 kmpl' '14.6 kmpl'
#  '23.08 kmpl' '18.27 kmpl' '18.56 kmpl' '17.9 kmpl' '25.5 kmpl'
#  '16.24 kmpl' '21.14 kmpl' '10.75 kmpl' '21.64 kmpl' '20.62 kmpl'
#  '15.73 kmpl' '15.43 kmpl' '20.68 kmpl' '14.21 kmpl' '18.19 kmpl'
#  '16.42 kmpl' '33.44 kmpl' '15 kmpl' '13.2 kmpl' '23.4 kmpl' '21.46 kmpl'
#  '17.33 kmpl' '25.17 kmpl' '20.97 kmpl' '13.4 kmpl' '16.93 kmpl'
#  '27.28 kmpl' '14.71 kmpl' '19.47 kmpl' '11.74 kmpl' '19.49 kmpl'
#  '12.5 kmpl' '17.14 kmpl' '18.07 kmpl' '12.18 kmpl' '14.025 kmpl'
#  '20.52 kmpl' '18.45 kmpl' '13.73 kmpl' '27.3 kmpl' '24.52 kmpl'
#  '25.32 kmpl' '26.49 kmpl' '11.9 kmpl' '23.5 kmpl' '12.9 kmpl'
#  '11.36 kmpl' '18.8 kmpl' '16.56 kmpl' '16.14 kmpl' '20.09 kmpl'
#  '16.65 kmpl' '26.32 kmpl' '20.04 kmpl' '17.19 kmpl' '19.12 kmpl'
#  '11.1 kmpl' '14.53 kmpl' '19.87 kmpl' '22.94 kmpl' '20.65 kmpl'
#  '22.35 kmpl' '14.74 kmpl' '20.85 kmpl' '18.12 kmpl' '19.44 kmpl'
#  '20.37 kmpl' '21.66 kmpl' '17.74 kmpl' '14.38 kmpl' '19.69 kmpl'
#  '16.3 kmpl' '11.79 kmpl' '22.5 kmpl' '15.04 kmpl' '22.95 kmpl'
#  '17.41 kmpl' '19.28 kmpl' '16.02 kmpl' '24.04 kmpl' '20.38 kmpl'
#  '15.96 kmpl' '17.2 kmpl' '14.28 kmpl' '10.5 kmpl' '23.64 kmpl'
#  '21.19 kmpl' '22.15 kmpl' '18.75 kmpl' '21.3 kmpl' '16.95 kmpl'
#  '23.57 kmpl' '22.69 kmpl' '22.56 kmpl' '15.4 kmpl' '22.32 kmpl'
#  '11.24 kmpl' '13.38 kmpl' '14.4 kmpl' '17.99 kmpl' '20.28 kmpl'
#  '13.8 kmpl' '19.95 kmpl' '17.68 kmpl' '21.56 kmpl' '12 kmpl' '21.63 kmpl'
#  '12.6 kmpl' '23.9 kmpl' '11.7 kmpl' '26.11 km/kg' '26.55 kmpl' '8 kmpl'
#  '22.61 kmpl' '26.08 km/kg' '31.59 km/kg' '20.88 km/kg' '25.6 kmpl'
#  '25.1 kmpl' '16.25 kmpl' '12.05 kmpl' '30.47 km/kg' '11.88 kmpl'
#  '15.5 kmpl' '35.6 km/kg' '14.2 kmpl' '15.17 kmpl' '15.2 kmpl'
#  '21.76 kmpl' '11.57 kmpl' '14.07 kmpl' '11.5 kmpl' '15.3 kmpl'
#  '19.59 kmpl' '8.9 kmpl' '140 kmpl' '15.81 kmpl' '22.27 kmpl' '24.5 kmpl'
#  '13.22 kmpl' '26.49 km/kg' '18.76 kmpl' '10.2 kmpl' '24.35 kmpl'
#  '27.97 kmpl' '11.2 kmpl' '15.97 kmpl' '10.93 kmpl' '19.62 kmpl'
#  '18.53 kmpl' '26.68 kmpl' '11.49 kmpl' '10.9 kmpl' '14.69 kmpl'
#  '19.83 kmpl' '18.4 kmpl' '21 kmpl' '19.8 kmpl' '18.09 kmpl' '16.96 kmpl'
#  '13.17 kmpl' '20.54 kmpl' '26.8 kmpl' '17.42 kmpl' '9.6 kmpl'
#  '21.43 kmpl' '17.88 kmpl' '16.13 kmpl' '23.8 kmpl' '10.54 kmpl'
#  '31.12 kmpl' '16.05 kmpl' '12.3 kmpl' '18.86 kmpl' '22.71 kmpl'
#  '14.72 kmpl' '14.16 kmpl' '14.99 kmpl' '23.03 kmpl' '19.08 kmpl'
#  '16.07 kmpl' '17.32 kmpl' '20.63 kmpl' '19.03 kmpl' '13.01 kmpl'
#  '22.25 kmpl' '27.4 kmpl' '11.4 kmpl' '14 kmpl' '24.97 kmpl' '12.4 kmpl'
#  '21.49 kmpl' '21.38 kmpl' '24.8 kmpl' '12.74 kmpl' '25.47 kmpl'
#  '19.71 kmpl' '18.55 kmpl' '18.33 kmpl' '14.49 kmpl' '16.73 kmpl'
#  '12.65 kmpl' '21.1 km/kg' '19.68 kmpl' '17.71 kmpl' '15.38 kmpl'
#  '21.02 kmpl' '12.81 kmpl' '20.58 kmpl' '16.78 kmpl' '16.34 kmpl'
#  '120 kmpl' '12.62 kmpl' '13.03 kmpl' '13.04 kmpl' '18.51 kmpl'
#  '21.12 kmpl' '6.7 kmpl' '21.04 kmpl' '26.83 kmpl' '110 kmpl' '20.34 kmpl'
#  '14.62 kmpl' '15.41 kmpl' '7.81 kmpl' '15.9 kmpl' '14.24 kmpl'
#  '11.81 kmpl' '11.67 kmpl' '13.47 kmpl' '12.33 kmpl' '26.21 kmpl'
#  '15.63 kmpl' '19.89 kmpl' '18.48 kmpl' '8.5 kmpl' '26.6 km/kg'
#  '19.72 kmpl' '14.9 kmpl' '18.25 kmpl' '24.4 kmpl' '23.22 kmpl' '9.8 kmpl'
#  '21.13 kmpl' '9.5 kmpl' '20.86 kmpl' '27 kmpl' '14.19 kmpl' '18.05 kmpl'
#  '11.33 kmpl' '16.94 kmpl' '9.2 kmpl' '23.3 kmpl' '13.49 kmpl'
#  '14.41 kmpl' '20.25 kmpl' '15.15 kmpl' '12.35 kmpl' '17.45 kmpl'
#  '32.26 kmpl' '15.34 kmpl' '12.98 kmpl' '14.01 kmpl' '9.74 kmpl'
#  '16.6 kmpl' '20.15 kmpl' '19.39 kmpl' '16.11 kmpl' '23.56 kmpl'
#  '15.01 kmpl' '10.6 kmpl' '12.83 kmpl' '14.75 kmpl' '10.8 kmpl'
#  '15.56 kmpl' '36 kmpl' '21.73 kmpl' '11.07 kmpl' '17.72 kmpl' '7.08 kmpl'
#  '19.64 kmpl' '18.67 kmpl' '20.64 kmpl' '18.44 kmpl' '19.05 kmpl'
#  '18.42 kmpl' '8.6 kmpl' '26.5 kmpl' '14.85 kmpl' '30.46 kmpl'
#  '26.11 kmpl' '13.06 kmpl' '18.32 kmpl' '19.65 kmpl' '25.35 kmpl'
#  '17.54 kmpl' '16.7 kmpl' '11.78 kmpl' '24.1 kmpl' '9.43 kmpl'
#  '24.07 kmpl' '22.8 kmpl' '9 kmpl' '12.63 kmpl' '16.72 kmpl' '10.7 kmpl'
#  '13.14 kmpl' '14.81 kmpl' '12.51 kmpl' '13.1 kmpl' '17.97 kmpl'
#  '12.28 kmpl' '20.27 kmpl' '27.03 kmpl' '12.78 kmpl' '21.8 kmpl'
#  '12.1 kmpl' '19.98 kmpl' '21.27 kmpl' '13.32 kmpl' '14.23 kmpl'
#  '13.87 kmpl' '26.78 km/kg' '14.34 kmpl' '11.96 kmpl' '16.39 kmpl'
#  '14.94 kmpl' '16.4 kmpl' '8.8 kmpl' '25.3 kmpl' '11.86 kmpl' '23.87 kmpl'
#  '22.37 kmpl' '19.09 kmpl' '10.26 kmpl' '12.04 kmpl' '11.8 kmpl'
#  '14.66 kmpl' '19.61 kmpl' '17.09 kmpl' '18.47 kmpl' '17.85 kmpl'
#  '14.95 kmpl' '13.45 kmpl' '11.18 kmpl' '12.19 kmpl' '17.67 kmpl'
#  '14.83 kmpl' '20.46 kmpl' '18.9 km/kg' '13.44 kmpl' '12.12 kmpl'
#  '26.55 km/kg' '10 kmpl' '11.25 kmpl' '18.84 kmpl' '21.58 kmpl'
#  '24.43 kmpl' '18.69 kmpl' '13.58 kmpl' '18.64 kmpl' '19.23 kmpl'
#  '9.26 kmpl' '26.82 kmpl' '12.97 kmpl' '8.7 kmpl' '13.33 kmpl'
#  '25.19 kmpl' '8.13 kmpl' '13.05 kmpl' '15.11 kmpl' '10.98 kmpl'
#  '8.45 kmpl' '18.43 kmpl']

# %%
# SEATS __________________________________________________
distinct_full_names_with_blank_seats = df[df['seats'].isnull()]['full_name'].unique()
print('Distinct full names with blank seats:')
for full_name in distinct_full_names_with_blank_seats:
    print(full_name)

df.loc[df['full_name'].isin(['2009 Maruti Estilo LXI', '2019 Nissan Kicks Diesel', '2010 Maruti Estilo LXI']), 'seats'] = 5
df.loc[df['full_name'] == '2008 Ford Endeavour 3.0 4x4 Thunder Plus', 'seats'] = 7

distinct_full_names_with_blank_seats = df[df['seats'].isnull()]['full_name'].unique()
print()
print('Distinct full names with blank seats:')
for full_name in distinct_full_names_with_blank_seats:
    print(full_name)


# ENGINE __________________________________________________
df['engine_capacity'] = df['engine_capacity'].str.replace('cc', '')


# KMS __________________________________________________
df['kms_driven'] = df['kms_driven'].str.replace('Kms', '')
df['kms_driven'] = df['kms_driven'].str.replace(',', '').str.strip()

# MAX POWER 
Correct_Max_Power = []
for power in df['max_power']:
    if pd.notna(power):
        if isinstance(power, str):
            if 'bhp' in power:
                num_bhp = float(re.search(r'\d+.?\d', power).group())
                Correct_Max_Power.append(num_bhp)
            elif 'PS' in power:
                num_ps = float(re.search(r'\d+.?\d', power).group())
                num_bhp = round(num_ps * 0.98632, 2)
                Correct_Max_Power.append(num_bhp)
            else:
                num = re.search(r'\d+\.?\d*', power)
                Correct_Max_Power.append(float(num.group()) if num else None)
        else:
            Correct_Max_Power.append(power)
    else:
        Correct_Max_Power.append(None)

Correct_Max_Power = [float(value) if value is not None else value for value in Correct_Max_Power]
df['max_power'] = Correct_Max_Power



# MILEAGE __________________________________________________
consumo_correto = []

for i in df['mileage']:
    match = re.search(r'(\d+.\d+|\d+)', str(i))

    if match:
        valor = float(match.group())

        if 'km/kg' in str(i):
            valor *= 1.40

        consumo_correto.append(valor if pd.notnull(i) else None)

while len(consumo_correto) < len(df):
    consumo_correto.append(None)

df['mileage'] = consumo_correto

media_mileage = df['mileage'].astype(float).mean()
df['mileage'].fillna(media_mileage, inplace=True)

# OWNER TYPE __________________________________________________

# Substituir os valores em branco ('') pela moda ('mode') da coluna 'owner_type'
moda_owner_type = df['owner_type'].mode()[0]  # Calcula a moda
df['owner_type'].replace('', moda_owner_type, inplace=True)

# INSURANCE __________________________________________________
#Deletar "insurance"
df['insurance'] = df['insurance'].str.replace('insurance', '')

#Substituir valores em branco e valores numéricos por 'No Insurance'
df['insurance'] = df['insurance'].apply(lambda x: 'No Insurance' if pd.isnull(x) or pd.api.types.is_numeric_dtype(x) else x)

#Corrigir "Third Party" com espaço extra
df['insurance'] = df['insurance'].str.replace('Third Party ', 'Third Party')
# Out:
# Distinct full names with blank seats:
# 2009 Maruti Estilo LXI
# 2019 Nissan Kicks Diesel
# 2008 Ford Endeavour 3.0 4x4 Thunder Plus
# 2010 Maruti Estilo LXI
#
# Distinct full names with blank seats:

# %%
#FullName ______________________________________

#ANO
# Extract the year and create a new column
df['ano'] = df['full_name'].str.extract(r'(\d{4})')

# Display the resulting DataFrame
print(df['ano'])

#MARCA
# Extract the first word after the year and create a new column
df['marca'] = df['full_name'].str.extract(r'\d{4}\s(\w+)')

# Print the resulting DataFrame
print(df['marca'])

#MODELO
# Get everything that comes after "marca"
df['modelo'] = df['full_name'].str.extract(r'\d{4}\s\w+\s(.+)')

# Print the resulting DataFrame
print(df['modelo'])
# Out:
# 0        2019
# 1        2018
# 2        2015
# 3        2021
# 4        2019
#          ...
# 13951    2021
# 13952    2017
# 13953    2017
# 13954    2017
# 13955    2015
# Name: ano, Length: 13956, dtype: object
# 0           Tata
# 1          Honda
# 2          Honda
# 3           Tata
# 4         Maruti
#           ...
# 13951        Kia
# 13952    Hyundai
# 13953      Skoda
# 13954     Maruti
# 13955      Honda
# Name: marca, Length: 13956, dtype: object
# 0                                        Tiago XZ Plus
# 1                                       WR-V i-VTEC VX
# 2                                       City i VTEC SV
# 3        New Safari XZA Plus Adventure Edition AT BSVI
# 4                                  Baleno 1.2 CVT Zeta
#                              ...
# 13951                                 Carnival Premium
# 13952                          i20 1.2 Magna Executive
# 13953                      Rapid 1.5 TDI Ambition BSIV
# 13954                                Vitara Brezza ZDi
# 13955                                  Amaze S i-Vtech
# Name: modelo, Length: 13956, dtype: object

# %%
#BODY TYPE ----------------------
#Replace the missing types and the ones that were wrong
df.loc[df['full_name'].isin(['2009 Maruti Estilo LXI', '2019 Nissan Kicks Diesel', '2010 Maruti Estilo LXI', '2019 Maruti Wagon R ZXI AMT 1.2BSIV',
                             '2016 Mercedes-Benz B Class B180 Sport', '2016 Mercedes-Benz A Class A200 D Sport Edition',
                             '2004 Tata Indigo Marina GLX', '2017 Volvo V40 D3 R Design']), 'body_type'] = 'Hatchback'
df.loc[df['full_name'].isin(['2005 Tata Sumo Victa EX 10/7 Str BSII', '2008 Tata Sumo CX', '2010 Tata New Safari DICOR 2.2 EX 4x2', 
                             '2017 Mahindra KUV 100 mFALCON G80 K8', '2019 Mahindra Bolero Camper GOLD ZX 2WD']), 'body_type'] = 'SUV'
df.loc[df['full_name'].isin(['2015 Honda Mobilio E i-DTEC', '2018 Maruti Eeco 5 Seater AC BSIV', '2016 Datsun GO Plus A']), 'body_type'] = 'MUV'
df.loc[df['full_name'].isin(['2021 BMW 7 Series 730Ld DPE Signature','2006 Hyundai Accent CRDi', '2007 Maruti SX4 Vxi BSIII',
                             '2020 Mercedes-Benz S-Class Maybach S560', '2004 Skoda Octavia 1.8 Turbo Petrol RS MT']), 'body_type'] = 'Sedan'
df.loc[df['full_name'].isin(['2012 Mercedes-Benz SLK-Class SLK 350', '2013 Mercedes-Benz E-Class E350 Cabriolet', 
                             '2009 Mercedes-Benz SLK-Class 55 AMG']), 'body_type'] = 'Convertibles'
df.loc[df['full_name'] == '2011 Jaguar XK R V8 Coupe', 'body_type'] = 'Coupe'
df.loc[df['full_name'].isin(['2015 Chevrolet Enjoy 1.4 LS 7', '2004 Maruti Versa DX2 8-SEATER BSIII TWIN A/C', '2021 Maruti Eeco 5 STR With AC Plus HTR CNG',
                             '2022 Maruti Eeco 5 Seater AC 2020-2022', '2022 Maruti Eeco 5 Seater AC BSVI', '2017 Maruti Eeco Flexi Green', 
                             '2013 Maruti Omni Limited Edition', '2021 Maruti Eeco CNG 5 Seater AC', '2019 Maruti Eeco CNG 5 Seater AC BSIV', 
                             '2019 Maruti Eeco 5 Seater AC', '2013 Maruti Eeco 5 Seater Standard BSIV', '2015 Maruti Omni CNG', 
                             '2015 Maruti Omni MPI CARGO BSIV', '2016 Maruti Eeco CNG 5 Seater AC BSIV', '2013 Toyota Innova 2.5 E Diesel MS 7-seater',
                             '2015 Chevrolet Enjoy 1.4 LS 7']), 'body_type'] = 'Minivans'
df.loc[df['full_name'].isin(['2014 Tata Xenon XT EX 4X2', '2019 Isuzu D-Max High']), 'body_type'] = 'Pickup'

# Check
distinct_full_names_with_blank_body_type = df[df['body_type'].isnull()]['full_name'].unique()
print('Distinct full names with blank body_type:')
for full_name in distinct_full_names_with_blank_body_type:
    print(full_name)
# Out:
# Distinct full names with blank body_type:

# %%
# Mudar formatos

df = df.astype({
    'seats': float,
    'engine_capacity': float,
    'kms_driven': float,
    'max_power': float,
    'ano': float,
    'marca': 'string',
    'modelo': 'string',
    'body_type': 'string',
    'mileage': float,
})

# %%
novo_valor = df['mileage'].mean()
df['mileage'] = df['mileage'].fillna(novo_valor)

# %%
novo_valor = df['engine_capacity'].mean()
df['engine_capacity'] = df['engine_capacity'].fillna(novo_valor)

# %%
novo_valor = df['max_power'].mean()
df['max_power'] = df['max_power'].fillna(novo_valor)

# %%
novo_valor = df['kms_driven'].mean()
df['kms_driven'] = df['kms_driven'].fillna(novo_valor)

# %%
# Check data types
data_types = df.dtypes
print("Data type by column:")
print(data_types)
# Out:
# Data type by column:
# full_name                    object
# registered_year              object
# engine_capacity             float64
# insurance                    object
# transmission_type            object
# kms_driven                  float64
# owner_type                   object
# fuel_type                    object
# max_power                   float64
# seats                       float64
# mileage                     float64
# body_type            string[python]
# city                         object
# resale_price_Lakh           float64
# ano                         float64
# marca                string[python]
# modelo               string[python]
# dtype: object

# %%
df = df.dropna(subset=['registered_year'])
# MARCA __________________________________________________
df = df.dropna(subset=['marca'])
# MODELO __________________________________________________
df = df.dropna(subset=['modelo'])

# %%
# Change formats

df = df.astype({
    'seats': float,
    'engine_capacity': float,
    'kms_driven': float,
    'max_power': float,
    'ano': float,
    'marca': 'string',
    'modelo': 'string',
   
})

# %%
#Create ID IDF  

# FUEL TYPE __________________________________________________

fuel_types = df['fuel_type']
n_docs = len(df)
idf = {}

# Uniques
unique_fuel_types = fuel_types.drop_duplicates()

print("FUEL TYPE".center(50, "_"))

for fuel_type in unique_fuel_types:
    k = sum(fuel_type == val for val in fuel_types)  
    idf[fuel_type] = np.log10(n_docs / (k + 1))  #+1 to avoid division by zero
    print(f'{fuel_type:>15}: {idf[fuel_type]:>10}')

# Create new column 
df['id_fuel_type'] = df['fuel_type'].map(idf)


print(df)
# Out:
# ____________________FUEL TYPE_____________________
#          Petrol: 0.1808108436013733
#          Diesel: 0.5145358569867878
#             CNG: 1.5242096868527688
#        Electric: 2.4584931940276564
#             LPG: 2.768863215945781
#                                                full_name registered_year  \
# 0                                2019 Tata Tiago XZ Plus        Nov 2019
# 1                              2018 Honda WR-V i-VTEC VX        Apr 2018
# 2                              2015 Honda City i VTEC SV        May 2015
# 3      2021 Tata New Safari XZA Plus Adventure Editio...            2021
# 4                        2019 Maruti Baleno 1.2 CVT Zeta        Jun 2019
# ...                                                  ...             ...
# 13951                          2021 Kia Carnival Premium            2021
# 13952               2017 Hyundai i20 1.2 Magna Executive        Dec 2017
# 13953             2017 Skoda Rapid 1.5 TDI Ambition BSIV        Jan 2018
# 13954                      2017 Maruti Vitara Brezza ZDi        Apr 2017
# 13955                         2015 Honda Amaze S i-Vtech        Mar 2015
#
#        engine_capacity      insurance transmission_type  kms_driven  \
# 0               1199.0    Third Party            Manual     30910.0
# 1               1199.0       Zero Dep            Manual     48089.0
# 2               1497.0    Third Party            Manual     51000.0
# 3               1956.0    Third Party         Automatic     30000.0
# 4               1197.0       Zero Dep         Automatic     61113.0
# ...                ...            ...               ...         ...
# 13951           2199.0    Third Party         Automatic     80000.0
# 13952           1197.0    Third Party            Manual     17923.0
# 13953           1498.0  Comprehensive            Manual     63389.0
# 13954           1248.0  Comprehensive            Manual     40000.0
# 13955           1198.0  Comprehensive            Manual     33046.0
#
#          owner_type fuel_type  max_power  seats   mileage  body_type  \
# 0       First Owner    Petrol       83.8    5.0  23.84000  Hatchback
# 1       Third Owner    Petrol       88.7    5.0  17.50000        SUV
# 2      Second Owner    Petrol      117.3    5.0  17.40000      Sedan
# 3       First Owner    Diesel      167.6    7.0  14.08000        SUV
# 4       First Owner    Petrol       83.1    5.0  21.40000  Hatchback
# ...             ...       ...        ...    ...       ...        ...
# 13951  Second Owner    Diesel      197.2    7.0  19.49405        MUV
# 13952   First Owner    Petrol       81.8    5.0  19.49405  Hatchback
# 13953  Second Owner    Diesel      108.6    5.0  19.49405      Sedan
# 13954  Second Owner    Diesel       88.5    5.0  19.49405        SUV
# 13955   First Owner    Petrol       86.7    5.0  19.49405      Sedan
#
#             city  resale_price_Lakh     ano    marca  \
# 0           Pune               5.66  2019.0     Tata
# 1         Jaipur               6.64  2018.0    Honda
# 2         Mumbai               5.65  2015.0    Honda
# 3         Mumbai              23.00  2021.0     Tata
# 4        Kolkata               6.87  2019.0   Maruti
# ...          ...                ...     ...      ...
# 13951  Hyderabad              26.50  2021.0      Kia
# 13952    Gurgaon               5.87  2017.0  Hyundai
# 13953  Hyderabad               7.43  2017.0    Skoda
# 13954  Bangalore               9.45  2017.0   Maruti
# 13955  Bangalore               4.55  2015.0    Honda
#
#                                               modelo  id_fuel_type
# 0                                      Tiago XZ Plus      0.180811
# 1                                     WR-V i-VTEC VX      0.180811
# 2                                     City i VTEC SV      0.180811
# 3      New Safari XZA Plus Adventure Edition AT BSVI      0.514536
# 4                                Baleno 1.2 CVT Zeta      0.180811
# ...                                              ...           ...
# 13951                               Carnival Premium      0.514536
# 13952                        i20 1.2 Magna Executive      0.180811
# 13953                    Rapid 1.5 TDI Ambition BSIV      0.514536
# 13954                              Vitara Brezza ZDi      0.514536
# 13955                                Amaze S i-Vtech      0.180811
#
# [13508 rows x 18 columns]

# %%
# categoria_marca __________________________________________________

fuel_types = df['marca']

n_docs = len(df)

idf = {}

# Uniques
unique_fuel_types = fuel_types.drop_duplicates()

print("marca".center(50, "_"))

for fuel_type in unique_fuel_types:
    k = sum(fuel_type == val for val in fuel_types)  
    idf[fuel_type] = np.log10(n_docs / (k + 1))   #+1 to avoid division by zero
    print(f'{fuel_type:>15}: {idf[fuel_type]:>10}')

# Create new column
df['id_categoria_marca'] = df['marca'].map(idf)

print(df)
# Out:
# ______________________marca_______________________
#            Tata: 1.2324145684656973
#           Honda: 0.9783027075803175
#          Maruti: 0.5428800869444625
#             BMW: 1.6420403354629296
#         Hyundai: 0.6762035848164187
#      Volkswagen: 1.4911045626947879
#         Renault: 1.4213210909875431
#        Mahindra: 1.3285017940816413
#            Ford: 1.4678332202817999
#          Toyota: 1.3664149195730433
#              MG: 1.9487474640186013
#          Jaguar: 2.267268191842918
#          Datsun: 2.2167771995796572
#       Chevrolet: 2.0233810823155056
#             Kia: 1.7485740093885056
#            Land: 2.4230208758654377
#          Nissan: 1.9603293365684165
#           Skoda: 1.694428404922618
#      Mitsubishi: 2.788168371141168
#           Volvo: 2.4773785381880304
#            Audi: 1.7861987782782633
#         Citroen: 3.22750106497143
#            Jeep: 1.9970521435931565
#           Force: 3.431621047627355
#            Fiat: 2.431621047627355
#           Lexus: 3.431621047627355
#            Mini: 3.0514098059157493
#           Isuzu: 3.130591051963374
#       OpelCorsa: 3.6534697972437113
#         Porsche: 3.0514098059157493
#         Bentley: 3.8295610562993927
#          Daewoo: 3.8295610562993927
#                                                full_name registered_year  \
# 0                                2019 Tata Tiago XZ Plus        Nov 2019
# 1                              2018 Honda WR-V i-VTEC VX        Apr 2018
# 2                              2015 Honda City i VTEC SV        May 2015
# 3      2021 Tata New Safari XZA Plus Adventure Editio...            2021
# 4                        2019 Maruti Baleno 1.2 CVT Zeta        Jun 2019
# ...                                                  ...             ...
# 13951                          2021 Kia Carnival Premium            2021
# 13952               2017 Hyundai i20 1.2 Magna Executive        Dec 2017
# 13953             2017 Skoda Rapid 1.5 TDI Ambition BSIV        Jan 2018
# 13954                      2017 Maruti Vitara Brezza ZDi        Apr 2017
# 13955                         2015 Honda Amaze S i-Vtech        Mar 2015
#
#        engine_capacity      insurance transmission_type  kms_driven  \
# 0               1199.0    Third Party            Manual     30910.0
# 1               1199.0       Zero Dep            Manual     48089.0
# 2               1497.0    Third Party            Manual     51000.0
# 3               1956.0    Third Party         Automatic     30000.0
# 4               1197.0       Zero Dep         Automatic     61113.0
# ...                ...            ...               ...         ...
# 13951           2199.0    Third Party         Automatic     80000.0
# 13952           1197.0    Third Party            Manual     17923.0
# 13953           1498.0  Comprehensive            Manual     63389.0
# 13954           1248.0  Comprehensive            Manual     40000.0
# 13955           1198.0  Comprehensive            Manual     33046.0
#
#          owner_type fuel_type  max_power  seats   mileage  body_type  \
# 0       First Owner    Petrol       83.8    5.0  23.84000  Hatchback
# 1       Third Owner    Petrol       88.7    5.0  17.50000        SUV
# 2      Second Owner    Petrol      117.3    5.0  17.40000      Sedan
# 3       First Owner    Diesel      167.6    7.0  14.08000        SUV
# 4       First Owner    Petrol       83.1    5.0  21.40000  Hatchback
# ...             ...       ...        ...    ...       ...        ...
# 13951  Second Owner    Diesel      197.2    7.0  19.49405        MUV
# 13952   First Owner    Petrol       81.8    5.0  19.49405  Hatchback
# 13953  Second Owner    Diesel      108.6    5.0  19.49405      Sedan
# 13954  Second Owner    Diesel       88.5    5.0  19.49405        SUV
# 13955   First Owner    Petrol       86.7    5.0  19.49405      Sedan
#
#             city  resale_price_Lakh     ano    marca  \
# 0           Pune               5.66  2019.0     Tata
# 1         Jaipur               6.64  2018.0    Honda
# 2         Mumbai               5.65  2015.0    Honda
# 3         Mumbai              23.00  2021.0     Tata
# 4        Kolkata               6.87  2019.0   Maruti
# ...          ...                ...     ...      ...
# 13951  Hyderabad              26.50  2021.0      Kia
# 13952    Gurgaon               5.87  2017.0  Hyundai
# 13953  Hyderabad               7.43  2017.0    Skoda
# 13954  Bangalore               9.45  2017.0   Maruti
# 13955  Bangalore               4.55  2015.0    Honda
#
#                                               modelo  id_fuel_type  \
# 0                                      Tiago XZ Plus      0.180811
# 1                                     WR-V i-VTEC VX      0.180811
# 2                                     City i VTEC SV      0.180811
# 3      New Safari XZA Plus Adventure Edition AT BSVI      0.514536
# 4                                Baleno 1.2 CVT Zeta      0.180811
# ...                                              ...           ...
# 13951                               Carnival Premium      0.514536
# 13952                        i20 1.2 Magna Executive      0.180811
# 13953                    Rapid 1.5 TDI Ambition BSIV      0.514536
# 13954                              Vitara Brezza ZDi      0.514536
# 13955                                Amaze S i-Vtech      0.180811
#
#        id_categoria_marca
# 0                1.232415
# 1                0.978303
# 2                0.978303
# 3                1.232415
# 4                0.542880
# ...                   ...
# 13951            1.748574
# 13952            0.676204
# 13953            1.694428
# 13954            0.542880
# 13955            0.978303
#
# [13508 rows x 19 columns]

# %%
# OWNER TYPE __________________________________________________

owner_types = df['owner_type']
n_docs = len(df)

idf = {}
# Uniques
unique_owner_types = owner_types.drop_duplicates()

for owner_type in unique_owner_types:
    k = sum(owner_type == val for val in owner_types) 
    idf[owner_type] = np.log10(n_docs / (k + 1))  

for owner_type, value in idf.items():
    print(f'{owner_type:>15}: {value:>10}')
# Create new column 
df['id_owner_type'] = df['owner_type'].map(idf)

print(df)
# Out:
#     First Owner: 0.1513159043723507
#     Third Owner: 1.3553447922231374
#    Second Owner: 0.6196441032904012
#     Fifth Owner: 2.5865230076130983
#    Fourth Owner: 2.1094017528934357
#                                                full_name registered_year  \
# 0                                2019 Tata Tiago XZ Plus        Nov 2019
# 1                              2018 Honda WR-V i-VTEC VX        Apr 2018
# 2                              2015 Honda City i VTEC SV        May 2015
# 3      2021 Tata New Safari XZA Plus Adventure Editio...            2021
# 4                        2019 Maruti Baleno 1.2 CVT Zeta        Jun 2019
# ...                                                  ...             ...
# 13951                          2021 Kia Carnival Premium            2021
# 13952               2017 Hyundai i20 1.2 Magna Executive        Dec 2017
# 13953             2017 Skoda Rapid 1.5 TDI Ambition BSIV        Jan 2018
# 13954                      2017 Maruti Vitara Brezza ZDi        Apr 2017
# 13955                         2015 Honda Amaze S i-Vtech        Mar 2015
#
#        engine_capacity      insurance transmission_type  kms_driven  \
# 0               1199.0    Third Party            Manual     30910.0
# 1               1199.0       Zero Dep            Manual     48089.0
# 2               1497.0    Third Party            Manual     51000.0
# 3               1956.0    Third Party         Automatic     30000.0
# 4               1197.0       Zero Dep         Automatic     61113.0
# ...                ...            ...               ...         ...
# 13951           2199.0    Third Party         Automatic     80000.0
# 13952           1197.0    Third Party            Manual     17923.0
# 13953           1498.0  Comprehensive            Manual     63389.0
# 13954           1248.0  Comprehensive            Manual     40000.0
# 13955           1198.0  Comprehensive            Manual     33046.0
#
#          owner_type fuel_type  max_power  seats   mileage  body_type  \
# 0       First Owner    Petrol       83.8    5.0  23.84000  Hatchback
# 1       Third Owner    Petrol       88.7    5.0  17.50000        SUV
# 2      Second Owner    Petrol      117.3    5.0  17.40000      Sedan
# 3       First Owner    Diesel      167.6    7.0  14.08000        SUV
# 4       First Owner    Petrol       83.1    5.0  21.40000  Hatchback
# ...             ...       ...        ...    ...       ...        ...
# 13951  Second Owner    Diesel      197.2    7.0  19.49405        MUV
# 13952   First Owner    Petrol       81.8    5.0  19.49405  Hatchback
# 13953  Second Owner    Diesel      108.6    5.0  19.49405      Sedan
# 13954  Second Owner    Diesel       88.5    5.0  19.49405        SUV
# 13955   First Owner    Petrol       86.7    5.0  19.49405      Sedan
#
#             city  resale_price_Lakh     ano    marca  \
# 0           Pune               5.66  2019.0     Tata
# 1         Jaipur               6.64  2018.0    Honda
# 2         Mumbai               5.65  2015.0    Honda
# 3         Mumbai              23.00  2021.0     Tata
# 4        Kolkata               6.87  2019.0   Maruti
# ...          ...                ...     ...      ...
# 13951  Hyderabad              26.50  2021.0      Kia
# 13952    Gurgaon               5.87  2017.0  Hyundai
# 13953  Hyderabad               7.43  2017.0    Skoda
# 13954  Bangalore               9.45  2017.0   Maruti
# 13955  Bangalore               4.55  2015.0    Honda
#
#                                               modelo  id_fuel_type  \
# 0                                      Tiago XZ Plus      0.180811
# 1                                     WR-V i-VTEC VX      0.180811
# 2                                     City i VTEC SV      0.180811
# 3      New Safari XZA Plus Adventure Edition AT BSVI      0.514536
# 4                                Baleno 1.2 CVT Zeta      0.180811
# ...                                              ...           ...
# 13951                               Carnival Premium      0.514536
# 13952                        i20 1.2 Magna Executive      0.180811
# 13953                    Rapid 1.5 TDI Ambition BSIV      0.514536
# 13954                              Vitara Brezza ZDi      0.514536
# 13955                                Amaze S i-Vtech      0.180811
#
#        id_categoria_marca  id_owner_type
# 0                1.232415       0.151316
# 1                0.978303       1.355345
# 2                0.978303       0.619644
# 3                1.232415       0.151316
# 4                0.542880       0.151316
# ...                   ...            ...
# 13951            1.748574       0.619644
# 13952            0.676204       0.151316
# 13953            1.694428       0.619644
# 13954            0.542880       0.619644
# 13955            0.978303       0.151316
#
# [13508 rows x 20 columns]

# %%
# INSURANCE __________________________________________________

insurance = df['insurance']
n_docs = len(df)
idf = {}

# Uniques
unique_insurance = insurance.drop_duplicates()

for insurance in unique_insurance:
    k = sum(insurance in row for row in df['insurance'])  
    idf[insurance] = np.log10(n_docs / (k + 1))  #+1 to avoid division by zero

for insurance, value in idf.items():
    print(f'{insurance:>15}: {value:>10}')

# Create new column 
df['id_insurance'] = df['insurance'].map(idf)
# Out:
#     Third Party: 0.2561672213768721
#        Zero Dep: 1.3090775235586007
#   Comprehensive: 0.44691375314468196
#   Not Available: 1.4145877083285747
#               1: 3.35243980157973
#               2: 3.5285310606354114
#    No Insurance: 3.35243980157973

# %%
# CITY __________________________________________________

city= df['city']
n_docs = len(df)
idf = {}

# Uniques
unique_cities = city.drop_duplicates()

for city in unique_cities:
    k = sum(city in row for row in df['city'])  
    idf[city] = np.log10(n_docs / (k + 1))  #+1 to avoid division by zero

for city, value in idf.items():
    print(f'{city:>15}: {value:>10}')

# Create new column 
df['id_city'] = df['city'].map(idf)
# Out:
#            Pune: 1.0951613137788256
#          Jaipur: 1.2805577942736048
#          Mumbai: 0.9237651759315242
#         Kolkata: 1.1705962136349577
#           Delhi: 0.768863215945781
#       Bangalore: 0.8686148605655614
#       Hyderabad: 1.027129429868669
#         Chennai: 1.130591051963374
#         Gurgaon: 1.2221060330847242
#      Chandigarh: 1.5940326093918438
#       Ahmedabad: 1.1106443702845317
#         Lucknow: 1.4981337597786497
#            Agra: 1.8777380209834806

# %%
valores_unicos_ano = df['ano'].unique()
print(valores_unicos_ano)
# Out:
# [2019. 2018. 2015. 2021. 2013. 2017. 2012. 2022. 2011. 2020. 2014. 2010.
#  2016. 2009. 2007. 2023. 2008. 2004. 2005. 2002. 2006. 2003.]

# %%
# MODELO _____________________________________

modelos = df['modelo']
n_docs = len(df)
idf = {}

# Uniques
unique_modelos = modelos.unique()

for modelo in unique_modelos:
    k = sum(modelo == val for val in modelos)  
    idf[modelo] = np.log10(n_docs / (k + 1))  #+1 to avoid division by zero

# Create new column 
df['id_modelos'] = df['modelo'].map(idf)

print(df)
# Out:
#                                                full_name registered_year  \
# 0                                2019 Tata Tiago XZ Plus        Nov 2019
# 1                              2018 Honda WR-V i-VTEC VX        Apr 2018
# 2                              2015 Honda City i VTEC SV        May 2015
# 3      2021 Tata New Safari XZA Plus Adventure Editio...            2021
# 4                        2019 Maruti Baleno 1.2 CVT Zeta        Jun 2019
# ...                                                  ...             ...
# 13951                          2021 Kia Carnival Premium            2021
# 13952               2017 Hyundai i20 1.2 Magna Executive        Dec 2017
# 13953             2017 Skoda Rapid 1.5 TDI Ambition BSIV        Jan 2018
# 13954                      2017 Maruti Vitara Brezza ZDi        Apr 2017
# 13955                         2015 Honda Amaze S i-Vtech        Mar 2015
#
#        engine_capacity      insurance transmission_type  kms_driven  \
# 0               1199.0    Third Party            Manual     30910.0
# 1               1199.0       Zero Dep            Manual     48089.0
# 2               1497.0    Third Party            Manual     51000.0
# 3               1956.0    Third Party         Automatic     30000.0
# 4               1197.0       Zero Dep         Automatic     61113.0
# ...                ...            ...               ...         ...
# 13951           2199.0    Third Party         Automatic     80000.0
# 13952           1197.0    Third Party            Manual     17923.0
# 13953           1498.0  Comprehensive            Manual     63389.0
# 13954           1248.0  Comprehensive            Manual     40000.0
# 13955           1198.0  Comprehensive            Manual     33046.0
#
#          owner_type fuel_type  max_power  seats  ...  resale_price_Lakh  \
# 0       First Owner    Petrol       83.8    5.0  ...               5.66
# 1       Third Owner    Petrol       88.7    5.0  ...               6.64
# 2      Second Owner    Petrol      117.3    5.0  ...               5.65
# 3       First Owner    Diesel      167.6    7.0  ...              23.00
# 4       First Owner    Petrol       83.1    5.0  ...               6.87
# ...             ...       ...        ...    ...  ...                ...
# 13951  Second Owner    Diesel      197.2    7.0  ...              26.50
# 13952   First Owner    Petrol       81.8    5.0  ...               5.87
# 13953  Second Owner    Diesel      108.6    5.0  ...               7.43
# 13954  Second Owner    Diesel       88.5    5.0  ...               9.45
# 13955   First Owner    Petrol       86.7    5.0  ...               4.55
#
#           ano    marca                                         modelo  \
# 0      2019.0     Tata                                  Tiago XZ Plus
# 1      2018.0    Honda                                 WR-V i-VTEC VX
# 2      2015.0    Honda                                 City i VTEC SV
# 3      2021.0     Tata  New Safari XZA Plus Adventure Edition AT BSVI
# 4      2019.0   Maruti                            Baleno 1.2 CVT Zeta
# ...       ...      ...                                            ...
# 13951  2021.0      Kia                               Carnival Premium
# 13952  2017.0  Hyundai                        i20 1.2 Magna Executive
# 13953  2017.0    Skoda                    Rapid 1.5 TDI Ambition BSIV
# 13954  2017.0   Maruti                              Vitara Brezza ZDi
# 13955  2015.0    Honda                                Amaze S i-Vtech
#
#        id_fuel_type id_categoria_marca id_owner_type  id_insurance   id_city  \
# 0          0.180811           1.232415      0.151316      0.256167  1.095161
# 1          0.180811           0.978303      1.355345      1.309078  1.280558
# 2          0.180811           0.978303      0.619644      0.256167  0.923765
# 3          0.514536           1.232415      0.151316      0.256167  0.923765
# 4          0.180811           0.542880      0.151316      1.309078  1.170596
# ...             ...                ...           ...           ...       ...
# 13951      0.514536           1.748574      0.619644      0.256167  1.027129
# 13952      0.180811           0.676204      0.151316      0.256167  1.222106
# 13953      0.514536           1.694428      0.619644      0.446914  1.027129
# 13954      0.514536           0.542880      0.619644      0.446914  0.868615
# 13955      0.180811           0.978303      0.151316      0.446914  0.868615
#
#        id_modelos
# 0        3.089198
# 1        2.406315
# 2        2.586523
# 3        3.653470
# 4        2.750380
# ...           ...
# 13951    3.653470
# 13952    2.954500
# 13953    3.285493
# 13954    2.750380
# 13955    2.431621
#
# [13508 rows x 23 columns]

# %%
#BODY TYPE __________________

body_type = df['body_type']
n_docs = len(df)
idf = {}

# Uniques
unique_body_type = body_type.drop_duplicates()

for body_type in unique_body_type:
    k = sum(body_type in row for row in df['body_type']) 
    idf[body_type] = np.log10(n_docs / (k + 1))  #+1 to avoid division by zero

for body_type, value in idf.items():
    print(f'{body_type:>15}: {value:>10}')

# Create new column 
df['id_body_type'] = df['body_type'].map(idf)

print(df)
# Out:
#       Hatchback: 0.36313833386560074
#             SUV: 0.6002632621852876
#           Sedan: 0.5776796017468651
#             MUV: 1.3502737398232225
#        Minivans: 2.298082139257138
#           Coupe: 3.285493011949117
#          Pickup: 3.0514098059157493
#           Wagon: 3.6534697972437113
#    Convertibles: 3.6534697972437113
#            Cars: 3.431621047627355
#                                                full_name registered_year  \
# 0                                2019 Tata Tiago XZ Plus        Nov 2019
# 1                              2018 Honda WR-V i-VTEC VX        Apr 2018
# 2                              2015 Honda City i VTEC SV        May 2015
# 3      2021 Tata New Safari XZA Plus Adventure Editio...            2021
# 4                        2019 Maruti Baleno 1.2 CVT Zeta        Jun 2019
# ...                                                  ...             ...
# 13951                          2021 Kia Carnival Premium            2021
# 13952               2017 Hyundai i20 1.2 Magna Executive        Dec 2017
# 13953             2017 Skoda Rapid 1.5 TDI Ambition BSIV        Jan 2018
# 13954                      2017 Maruti Vitara Brezza ZDi        Apr 2017
# 13955                         2015 Honda Amaze S i-Vtech        Mar 2015
#
#        engine_capacity      insurance transmission_type  kms_driven  \
# 0               1199.0    Third Party            Manual     30910.0
# 1               1199.0       Zero Dep            Manual     48089.0
# 2               1497.0    Third Party            Manual     51000.0
# 3               1956.0    Third Party         Automatic     30000.0
# 4               1197.0       Zero Dep         Automatic     61113.0
# ...                ...            ...               ...         ...
# 13951           2199.0    Third Party         Automatic     80000.0
# 13952           1197.0    Third Party            Manual     17923.0
# 13953           1498.0  Comprehensive            Manual     63389.0
# 13954           1248.0  Comprehensive            Manual     40000.0
# 13955           1198.0  Comprehensive            Manual     33046.0
#
#          owner_type fuel_type  max_power  seats  ...     ano    marca  \
# 0       First Owner    Petrol       83.8    5.0  ...  2019.0     Tata
# 1       Third Owner    Petrol       88.7    5.0  ...  2018.0    Honda
# 2      Second Owner    Petrol      117.3    5.0  ...  2015.0    Honda
# 3       First Owner    Diesel      167.6    7.0  ...  2021.0     Tata
# 4       First Owner    Petrol       83.1    5.0  ...  2019.0   Maruti
# ...             ...       ...        ...    ...  ...     ...      ...
# 13951  Second Owner    Diesel      197.2    7.0  ...  2021.0      Kia
# 13952   First Owner    Petrol       81.8    5.0  ...  2017.0  Hyundai
# 13953  Second Owner    Diesel      108.6    5.0  ...  2017.0    Skoda
# 13954  Second Owner    Diesel       88.5    5.0  ...  2017.0   Maruti
# 13955   First Owner    Petrol       86.7    5.0  ...  2015.0    Honda
#
#                                               modelo  id_fuel_type  \
# 0                                      Tiago XZ Plus      0.180811
# 1                                     WR-V i-VTEC VX      0.180811
# 2                                     City i VTEC SV      0.180811
# 3      New Safari XZA Plus Adventure Edition AT BSVI      0.514536
# 4                                Baleno 1.2 CVT Zeta      0.180811
# ...                                              ...           ...
# 13951                               Carnival Premium      0.514536
# 13952                        i20 1.2 Magna Executive      0.180811
# 13953                    Rapid 1.5 TDI Ambition BSIV      0.514536
# 13954                              Vitara Brezza ZDi      0.514536
# 13955                                Amaze S i-Vtech      0.180811
#
#        id_categoria_marca id_owner_type id_insurance   id_city  id_modelos  \
# 0                1.232415      0.151316     0.256167  1.095161    3.089198
# 1                0.978303      1.355345     1.309078  1.280558    2.406315
# 2                0.978303      0.619644     0.256167  0.923765    2.586523
# 3                1.232415      0.151316     0.256167  0.923765    3.653470
# 4                0.542880      0.151316     1.309078  1.170596    2.750380
# ...                   ...           ...          ...       ...         ...
# 13951            1.748574      0.619644     0.256167  1.027129    3.653470
# 13952            0.676204      0.151316     0.256167  1.222106    2.954500
# 13953            1.694428      0.619644     0.446914  1.027129    3.285493
# 13954            0.542880      0.619644     0.446914  0.868615    2.750380
# 13955            0.978303      0.151316     0.446914  0.868615    2.431621
#
#        id_body_type
# 0          0.363138
# 1          0.600263
# 2          0.577680
# 3          0.600263
# 4          0.363138
# ...             ...
# 13951      1.350274
# 13952      0.363138
# 13953      0.577680
# 13954      0.600263
# 13955      0.577680
#
# [13508 rows x 24 columns]

# %%
# Transmissao _____________________________________

transmissao = df['transmission_type']

n_docs = len(df)


transmissao_counts = transmissao.value_counts()

idf = {}

for tipo_transmissao, count in transmissao_counts.items():
    idf[tipo_transmissao] = np.log10(n_docs / (count + 1))  #+1 to avoid division by zero

# Create new column 
df['id_transmissao'] = df['transmission_type'].map(idf)


print(df)
# Out:
#                                                full_name registered_year  \
# 0                                2019 Tata Tiago XZ Plus        Nov 2019
# 1                              2018 Honda WR-V i-VTEC VX        Apr 2018
# 2                              2015 Honda City i VTEC SV        May 2015
# 3      2021 Tata New Safari XZA Plus Adventure Editio...            2021
# 4                        2019 Maruti Baleno 1.2 CVT Zeta        Jun 2019
# ...                                                  ...             ...
# 13951                          2021 Kia Carnival Premium            2021
# 13952               2017 Hyundai i20 1.2 Magna Executive        Dec 2017
# 13953             2017 Skoda Rapid 1.5 TDI Ambition BSIV        Jan 2018
# 13954                      2017 Maruti Vitara Brezza ZDi        Apr 2017
# 13955                         2015 Honda Amaze S i-Vtech        Mar 2015
#
#        engine_capacity      insurance transmission_type  kms_driven  \
# 0               1199.0    Third Party            Manual     30910.0
# 1               1199.0       Zero Dep            Manual     48089.0
# 2               1497.0    Third Party            Manual     51000.0
# 3               1956.0    Third Party         Automatic     30000.0
# 4               1197.0       Zero Dep         Automatic     61113.0
# ...                ...            ...               ...         ...
# 13951           2199.0    Third Party         Automatic     80000.0
# 13952           1197.0    Third Party            Manual     17923.0
# 13953           1498.0  Comprehensive            Manual     63389.0
# 13954           1248.0  Comprehensive            Manual     40000.0
# 13955           1198.0  Comprehensive            Manual     33046.0
#
#          owner_type fuel_type  max_power  seats  ...    marca  \
# 0       First Owner    Petrol       83.8    5.0  ...     Tata
# 1       Third Owner    Petrol       88.7    5.0  ...    Honda
# 2      Second Owner    Petrol      117.3    5.0  ...    Honda
# 3       First Owner    Diesel      167.6    7.0  ...     Tata
# 4       First Owner    Petrol       83.1    5.0  ...   Maruti
# ...             ...       ...        ...    ...  ...      ...
# 13951  Second Owner    Diesel      197.2    7.0  ...      Kia
# 13952   First Owner    Petrol       81.8    5.0  ...  Hyundai
# 13953  Second Owner    Diesel      108.6    5.0  ...    Skoda
# 13954  Second Owner    Diesel       88.5    5.0  ...   Maruti
# 13955   First Owner    Petrol       86.7    5.0  ...    Honda
#
#                                               modelo id_fuel_type  \
# 0                                      Tiago XZ Plus     0.180811
# 1                                     WR-V i-VTEC VX     0.180811
# 2                                     City i VTEC SV     0.180811
# 3      New Safari XZA Plus Adventure Edition AT BSVI     0.514536
# 4                                Baleno 1.2 CVT Zeta     0.180811
# ...                                              ...          ...
# 13951                               Carnival Premium     0.514536
# 13952                        i20 1.2 Magna Executive     0.180811
# 13953                    Rapid 1.5 TDI Ambition BSIV     0.514536
# 13954                              Vitara Brezza ZDi     0.514536
# 13955                                Amaze S i-Vtech     0.180811
#
#        id_categoria_marca  id_owner_type id_insurance   id_city  id_modelos  \
# 0                1.232415       0.151316     0.256167  1.095161    3.089198
# 1                0.978303       1.355345     1.309078  1.280558    2.406315
# 2                0.978303       0.619644     0.256167  0.923765    2.586523
# 3                1.232415       0.151316     0.256167  0.923765    3.653470
# 4                0.542880       0.151316     1.309078  1.170596    2.750380
# ...                   ...            ...          ...       ...         ...
# 13951            1.748574       0.619644     0.256167  1.027129    3.653470
# 13952            0.676204       0.151316     0.256167  1.222106    2.954500
# 13953            1.694428       0.619644     0.446914  1.027129    3.285493
# 13954            0.542880       0.619644     0.446914  0.868615    2.750380
# 13955            0.978303       0.151316     0.446914  0.868615    2.431621
#
#        id_body_type  id_transmissao
# 0          0.363138        0.130634
# 1          0.600263        0.130634
# 2          0.577680        0.130634
# 3          0.600263        0.585160
# 4          0.363138        0.585160
# ...             ...             ...
# 13951      1.350274        0.585160
# 13952      0.363138        0.130634
# 13953      0.577680        0.130634
# 13954      0.600263        0.130634
# 13955      0.577680        0.130634
#
# [13508 rows x 25 columns]

# %%
df = df.astype({
    'seats': float,
    'engine_capacity': float,
    'kms_driven': float,
    'max_power': float,
    'ano': float,
    'marca': 'string',
    'modelo': 'string',
    'id_categoria_marca': float,
})

# %%
contagem_nulos = df.isnull().sum()

print(f"O número de valores nulos na coluna é: {contagem_nulos}")
# Out:
# O número de valores nulos na coluna é: full_name             0
# registered_year       0
# engine_capacity       0
# insurance             0
# transmission_type     0
# kms_driven            0
# owner_type            0
# fuel_type             0
# max_power             0
# seats                 0
# mileage               0
# body_type             0
# city                  0
# resale_price_Lakh     0
# ano                   0
# marca                 0
# modelo                0
# id_fuel_type          0
# id_categoria_marca    0
# id_owner_type         0
# id_insurance          0
# id_city               0
# id_modelos            0
# id_body_type          0
# id_transmissao        0
# dtype: int64

# %%
#correlation  

# Select columns
columns_of_interest = ['id_transmissao', 'id_body_type','id_modelos','id_categoria_marca', 'mileage','ano','id_city','id_insurance','seats','engine_capacity','id_fuel_type','kms_driven','max_power','id_owner_type','resale_price_Lakh']
subset_df = df[columns_of_interest]

plt.figure(figsize=(3, 5))

# Creat heatmap
heatmap = sns.heatmap(subset_df.corr()[['resale_price_Lakh']].sort_values(by='resale_price_Lakh', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with resale_price_Lakh', fontdict={'fontsize': 12}, pad=16)

plt.show()

# %%
#Export
#Not the target
colunas_selecionadas = ['id_transmissao', 'id_body_type','id_modelos','id_categoria_marca', 'mileage','ano','id_city','id_insurance','seats','engine_capacity','id_fuel_type','kms_driven','max_power','id_owner_type','resale_price_Lakh']


if set(colunas_selecionadas).issubset(df.columns):
    df_selecionado = df[colunas_selecionadas]
    df_selecionado.to_csv('Cenario7.csv', index=False)

# %%
df.columns
# Out:
# Index(['full_name', 'registered_year', 'engine_capacity', 'insurance',
#        'transmission_type', 'kms_driven', 'owner_type', 'fuel_type',
#        'max_power', 'seats', 'mileage', 'body_type', 'city',
#        'resale_price_Lakh', 'ano', 'marca', 'modelo', 'id_fuel_type',
#        'id_categoria_marca', 'id_owner_type', 'id_insurance', 'id_city',
#        'id_modelos', 'id_body_type', 'id_transmissao'],
#       dtype='object')

# %%
#Export
#Not the target
colunas_selecionadas = ['transmission_type','id_transmissao','body_type','id_body_type','modelo','id_modelos','marca','id_categoria_marca', 'mileage','ano','city','id_city','insurance','id_insurance','seats','engine_capacity','fuel_type','id_fuel_type','kms_driven','max_power','owner_type','id_owner_type','resale_price_Lakh']


if set(colunas_selecionadas).issubset(df.columns):
    df_selecionado = df[colunas_selecionadas]
    df_selecionado.to_csv('todasCenario7.csv', index=False)
